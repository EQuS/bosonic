# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Import

# %%
from bosonic_jax import Qubit, GKPQubit, execute, BosonicRegister, BosonicCircuit, PhaseRotationGate, \
                    DisplaceGate, NumSplitCDGate, QubitRotationGate, NumDepQubitRotationGate, CDGate, CatQubit, HGate, \
                    gen_custom_gate
import jax.numpy as jnp
import matplotlib.pyplot as plt

# %% [markdown]
# # Create Bosonic Circuit

# %%
# Circuit containing 1 cavity and 1 qubit
breg = BosonicRegister([Qubit(), Qubit()])
bcirc = BosonicCircuit(breg)

# set up circuit
bcirc.reset() # initialize each qubit in |+z>
bcirc.add(HGate, 0)

results = execute(bcirc, "unitary_jax")

results.plot(bcirc, 0)
results.plot(bcirc, 1)

# %% [markdown]
# # Custom Gate

# %%
custom_HGate = gen_custom_gate(Us = [jnp.array([[1, 1], [1, -1]]) / jnp.sqrt(2)])

# %%
# Circuit containing 1 cavity and 1 qubit
breg = BosonicRegister([Qubit(), Qubit()])
bcirc = BosonicCircuit(breg)

# set up circuit
bcirc.reset() # initialize each qubit in |+z>
bcirc.add(custom_HGate, 0)

results = execute(bcirc, "unitary_jax")

results.plot(bcirc, 0)
results.plot(bcirc, 1)
