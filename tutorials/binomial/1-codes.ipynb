# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bosonic_jax import BinomialQubit, BosonicRegister, BosonicCircuit, execute, plot_wigner
import bosonic_jax.jax_qutip as jqt

# %%
qubit = BinomialQubit(params={"N":50})
breg = BosonicRegister([qubit])
bcirc = BosonicCircuit(breg)

# %%
qubit.plot_code_states()

# %%
qubit.plot_code_states(qp_type="qfunc")

# %%
bcirc.plot(0) # plot initial state

# set up circuit
bcirc.reset()
bcirc.x(0)

# %%
# %timeit results = execute(bcirc, "unitary_jax")
# Out:
# 4.95 µs ± 158 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
results.plot(bcirc,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 results.plot(bcirc,0)
#
# NameError: name 'results' is not defined
