# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bosonic import BinomialQubit, BosonicRegister, BosonicCircuit, execute
from jaxquantum import plot_wigner
import jaxquantum as jqt
# Out:
# /home/shanj/miniconda3/envs/jax-new/lib/python3.12/site-packages/qutip/__init__.py:66: UserWarning: The new version of Cython, (>= 3.0.0) is not supported.
#   warnings.warn(

# %%
qubit = BinomialQubit(params={"N":50}, name="")
breg = BosonicRegister([qubit])
bcirc = BosonicCircuit(breg)
qubit.plot_code_states()
# Out:
# /home/shanj/Github/EQuS/jax/bosonic/bosonic/codes/base.py:282: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
qubit.plot_code_states(qp_type="qfunc")

# %%
bcirc.plot(0) # plot initial state

# set up circuit
bcirc.reset()
bcirc.x(0)

# %%
# %timeit results = execute(bcirc, "unitary_jax")
# Out:
# 10.2 µs ± 164 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
results = execute(bcirc, "unitary_jax")
results.plot(bcirc,0)
